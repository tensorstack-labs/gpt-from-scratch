# %% [markdown]
# # 🧠 TensorStack Chapter 3: Multi-Head Self-Attention from Scratch in PyTorch
# [![YouTube Video](https://img.shields.io/badge/YouTube-Watch%20Chapter%203-red)](https://youtu.be/jYohHdwnnd0)
#
# Welcome to Chapter 3! In this notebook, we code and visualize every stage of Multi-Head Self-Attention from first principles.

# %%
import torch
import torch.nn as nn
from multi_head_attention import SelfAttention_v2, CausalAttention, MultiHeadAttention

torch.manual_seed(123)
batch_size = 2
context_len = 6
d_in = 768
d_out = 768

inputs = torch.randn(batch_size, context_len, d_in)
mha = MultiHeadAttention(d_in=d_in, d_out=d_out, context_len=context_len, dropout=0.1, num_heads=12)
outputs = mha(inputs)
print('Output shape:', outputs.shape)
